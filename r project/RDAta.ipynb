# %%
import os
import pandas as pd
 
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr
 
pandas2ri.activate()
 
base = importr('base')
base.load("affairs.RData");
rdf = base.mget(base.ls())
 
df = {}
for i,f in enumerate(base.names(rdf)):
    df[f] = pandas2ri.ri2py_dataframe(rdf[i])
 
for k,v in df.items():
    print(v.head())
# Out:
#    id  male   age  yrsmarr  kids  relig  educ  occup  ratemarr  naffairs  \
# 1   4     1  37.0     10.0     0      3    18      7         4         0
# 2   5     0  27.0      4.0     0      4    14      6         4         0
# 3   6     1  27.0      1.5     0      3    18      4         4         3
# 4  11     0  32.0     15.0     1      1    12      1         4         0
# 5  12     0  27.0      4.0     1      3    17      1         5         3
#
#    affair  vryhap  hapavg  avgmarr  unhap  vryrel  smerel  slghtrel  notrel
# 1       0       0       1        0      0       0       0         1       0
# 2       0       0       1        0      0       0       1         0       0
# 3       1       0       1        0      0       0       0         1       0
# 4       0       0       1        0      0       0       0         0       0
# 5       1       1       0        0      0       0       0         1       0

# %%
v.dtypes
# Out:
# id            int32
# male          int32
# age         float64
# yrsmarr     float64
# kids          int32
# relig         int32
# educ          int32
# occup         int32
# ratemarr      int32
# naffairs      int32
# affair        int32
# vryhap        int32
# hapavg        int32
# avgmarr       int32
# unhap         int32
# vryrel        int32
# smerel        int32
# slghtrel      int32
# notrel        int32
# dtype: object

# %%
v.head()
# Out:
#    id  male   age  yrsmarr  kids  relig  educ  occup  ratemarr  naffairs  \
# 1   4     1  37.0     10.0     0      3    18      7         4         0
# 2   5     0  27.0      4.0     0      4    14      6         4         0
# 3   6     1  27.0      1.5     0      3    18      4         4         3
# 4  11     0  32.0     15.0     1      1    12      1         4         0
# 5  12     0  27.0      4.0     1      3    17      1         5         3
#
#    affair  vryhap  hapavg  avgmarr  unhap  vryrel  smerel  slghtrel  notrel
# 1       0       0       1        0      0       0       0         1       0
# 2       0       0       1        0      0       0       1         0       0
# 3       1       0       1        0      0       0       0         1       0
# 4       0       0       1        0      0       0       0         0       0
# 5       1       1       0        0      0       0       0         1       0

# %%
pandas2ri.activate()
 
base = importr('base')
base.load("apple.RData");
rdf = base.mget(base.ls())
 
df = {}
for i,f in enumerate(base.names(rdf)):
    df[f] = pandas2ri.ri2py_dataframe(rdf[i])
 
for k,v in df.items():
    print(v.head())
# Out:
#    id  male   age  yrsmarr  kids  relig  educ  occup  ratemarr  naffairs  \
# 1   4     1  37.0     10.0     0      3    18      7         4         0
# 2   5     0  27.0      4.0     0      4    14      6         4         0
# 3   6     1  27.0      1.5     0      3    18      4         4         3
# 4  11     0  32.0     15.0     1      1    12      1         4         0
# 5  12     0  27.0      4.0     1      3    17      1         5         3
#
#    affair  vryhap  hapavg  avgmarr  unhap  vryrel  smerel  slghtrel  notrel
# 1       0       0       1        0      0       0       0         1       0
# 2       0       0       1        0      0       0       1         0       0
# 3       1       0       1        0      0       0       0         1       0
# 4       0       0       1        0      0       0       0         0       0
# 5       1       1       0        0      0       0       0         1       0
# ...

# %%
v.head()
# Out:
#       id  educ    date state  regprc  ecoprc  inseason  hhsize  male  faminc  \
# 1  10002    16  111597    SD    1.19    1.19         1       4     0      45
# 2  10004    16  121897    KS    0.59    0.79         0       1     0      65
# 3  10034    18  111097    MI    0.59    0.99         1       3     0      65
# 4  10035    12  111597    TN    0.89    1.09         1       2     1      55
# 5  10039    15  122997    NY    0.89    1.09         0       1     1      25
#
#    age  reglbs    ecolbs  numlt5  num5_17  num18_64  numgt64
# 1   43     2.0  2.000000       0        1         3        0
# 2   37     0.0  2.000000       0        0         1        0
# 3   44     0.0  2.666667       0        2         1        0
# 4   55     3.0  0.000000       0        0         2        0
# 5   22     0.0  3.000000       0        0         1        0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car.csv', delimiter='\t')

# %%
df.columns
# Out:
# Index([u'make', u'price', u'mpg', u'rep78', u'headroom', u'trunk', u'weight',
#        u'length', u'turn', u'displacement', u'gear_ratio', u'foreign'],
#       dtype='object')

# %%
df.head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    NaN       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign
# 0           121        3.58  Domestic
# 1           258        2.53  Domestic
# 2           121        3.08  Domestic
# 3           196        2.93  Domestic
# 4           350        2.41  Domestic

# %%
df.head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    NaN       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign
# 0           121        3.58  Domestic
# 1           258        2.53  Domestic
# 2           121        3.08  Domestic
# 3           196        2.93  Domestic
# 4           350        2.41  Domestic

# %%
dummies = pd.get_dummies(df['foreign'])

# %%
dummies.head()
# Out:
#    Domestic  Foreign
# 0         1        0
# 1         1        0
# 2         1        0
# 3         1        0
# 4         1        0

# %%
df.foreign.unique()
# Out:
# array(['Domestic', 'Foreign'], dtype=object)

# %%
df[df.foreign=='Domestic'].head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    NaN       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign
# 0           121        3.58  Domestic
# 1           258        2.53  Domestic
# 2           121        3.08  Domestic
# 3           196        2.93  Domestic
# 4           350        2.41  Domestic

# %%
names = {0:'Foreign', 1:'Domestic'}
for elem in df['foreign'].unique():
    df[names[elem]] = df['foreign'] == elem
return df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-c10058e38a73> in <module>()
#       1 names = {0:'Foreign', 1:'Domestic'}
#       2 for elem in df['foreign'].unique():
# ----> 3     df[names[elem]] = df['foreign'] == elem
#       4 return df
#
# KeyError: 'Domestic'

# %%
df= pd.concat([df,dummies],axis = 1)

# %%
df.head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    NaN       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign  Domestic  Foreign
# 0           121        3.58  Domestic         1        0
# 1           258        2.53  Domestic         1        0
# 2           121        3.08  Domestic         1        0
# 3           196        2.93  Domestic         1        0
# 4           350        2.41  Domestic         1        0

# %%
df = df.merge(dummies, left_index=True, right_index=True)

# %%
df.head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    NaN       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign  Domestic_x  Foreign_x  Domestic_y  \
# 0           121        3.58  Domestic           1          0           1
# 1           258        2.53  Domestic           1          0           1
# 2           121        3.08  Domestic           1          0           1
# 3           196        2.93  Domestic           1          0           1
# 4           350        2.41  Domestic           1          0           1
#
#    Foreign_y
# 0          0
# 1          0
# 2          0
# 3          0
# ...

# %%
from __future__ import print_function
from statsmodels.compat import lzip

import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import itertools
from itertools import chain, combinations
import statsmodels.formula.api as smf
import scipy.stats as scipystats
import statsmodels.api as sm
import statsmodels.stats.stattools as stools
import statsmodels.stats as stats 
from statsmodels.graphics.regressionplots import *
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from sklearn.model_selection import train_test_split
import math

# %%
df.corr()
# Out:
#                  price       mpg     rep78  headroom     trunk    weight  \
# price         1.000000 -0.468597  0.006553  0.114506  0.314332  0.538611
# mpg          -0.468597  1.000000  0.402340 -0.413803 -0.581585 -0.807175
# rep78         0.006553  0.402340  1.000000 -0.147998 -0.157243 -0.400344
# headroom      0.114506 -0.413803 -0.147998  1.000000  0.662011  0.483456
# trunk         0.314332 -0.581585 -0.157243  0.662011  1.000000  0.672206
# weight        0.538611 -0.807175 -0.400344  0.483456  0.672206  1.000000
# length        0.431831 -0.795779 -0.360565  0.516295  0.726596  0.946009
# turn          0.309617 -0.719186 -0.496131  0.424465  0.601059  0.857443
# displacement  0.494943 -0.705643 -0.411943  0.474491  0.608635  0.894896
# gear_ratio   -0.313661  0.616177  0.410340 -0.377852 -0.508665 -0.759258
# Domestic     -0.048719 -0.393397 -0.592237  0.293853  0.359435  0.592830
# Foreign       0.048719  0.393397  0.592237 -0.293853 -0.359435 -0.592830
#
# ...

# %%
df.describe()
# Out:
#               price        mpg      rep78   headroom      trunk       weight  \
# count     74.000000  74.000000  69.000000  74.000000  74.000000    74.000000
# mean    6165.256757  21.297297   3.405797   2.993243  13.756757  3019.459459
# std     2949.495885   5.785503   0.989932   0.845995   4.277404   777.193567
# min     3291.000000  12.000000   1.000000   1.500000   5.000000  1760.000000
# 25%     4220.250000  18.000000   3.000000   2.500000  10.250000  2250.000000
# 50%     5006.500000  20.000000   3.000000   3.000000  14.000000  3190.000000
# 75%     6332.250000  24.750000   4.000000   3.500000  16.750000  3600.000000
# max    15906.000000  41.000000   5.000000   5.000000  23.000000  4840.000000
#
#            length       turn  displacement  gear_ratio   Domestic    Foreign
# count   74.000000  74.000000     74.000000   74.000000  74.000000  74.000000
# mean   187.932432  39.648649    197.297297    3.014865   0.702703   0.297297
# ...

# %%
price ~ mpg+weight+displacement+length+gear_ratio+foreign+trunk, data=cars)  # build linear regression model on full data

# %%
lm = smf.ols(formula = "crime ~ pctmetro + poverty + single + pctwhite + murder ", data = crime).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-f1ead302aacd> in <module>()
# ----> 1 lm = smf.ols(formula = "crime ~ pctmetro + poverty + single + pctwhite + murder ", data = crime).fit()
#       2 print_model = lm.summary()
#       3 print(print_model)
#
# NameError: name 'crime' is not defined

# %%
lm = smf.ols(formula='price ~ mpg+weight+displacement+length+gear_ratio+Foreign+trunk', data =df).fit()
model = lm.summary()
print(model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     12.18
# Date:                Mon, 13 May 2019   Prob (F-statistic):           7.03e-10
# Time:                        07:22:17   Log-Likelihood:                -665.03
# No. Observations:                  74   AIC:                             1346.
# Df Residuals:                      66   BIC:                             1364.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     5604.2285   6078.517      0.922      0.360   -6531.923    1.77e+04
# ...

# %% [markdown]
# # Influence tests
#
#
# Once created, an object of class OLSInfluence holds attributes and methods that allow users to assess the influence of each observation. For example, we can compute and extract the first few rows of DFbetas by:

# %%
from statsmodels.stats.outliers_influence import OLSInfluence
test_class = OLSInfluence(lm)
test_class.dfbetas[:5,:]
# Out:
# array([[ 1.73452651e-03,  8.54494112e-04, -1.75893035e-03,
#          1.55040204e-03,  3.84160245e-04, -3.95936816e-03,
#          4.15408305e-03,  1.08426592e-03],
#        [-8.23417499e-01,  3.66045919e-01, -5.34194378e-01,
#         -1.94171663e-02,  8.70180400e-01,  8.32173256e-02,
#          1.49927639e-01,  2.56716542e-03],
#        [-5.26237144e-02,  2.76626408e-02, -3.60161363e-02,
#          3.61721165e-02,  5.24077774e-02, -9.80564385e-05,
#          4.50232591e-02, -1.88780517e-02],
#        [-5.12036502e-04,  1.22212586e-03, -8.51263355e-03,
#          2.34636641e-02,  1.67492730e-03, -1.69287419e-03,
#          2.42722800e-02, -1.66401903e-02],
#        [ 2.08435775e-02, -9.11847321e-03,  2.83843087e-02,
#         -3.44002097e-02, -2.72471911e-02,  9.61536161e-03,
#         -2.12957665e-02, -1.48232702e-02]])

# %% [markdown]
# Explore other options by typing dir(influence_test)
#
# Useful information on leverage can also be plotted:

# %%
from statsmodels.graphics.regressionplots import plot_leverage_resid2
fig, ax = plt.subplots(figsize=(8,6))
fig = plot_leverage_resid2(lm, ax = ax)

# %% [markdown]
# # Multicollinearity¶
# Condition number:

# %%
np.linalg.cond(lm.model.exog)
# Out:
# 80123.32765637622

# %% [markdown]
# # Heteroskedasticity tests¶
# Breush-Pagan test:

# %%
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(lm.resid, lm.model.exog)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 18.484589126965304),
#  ('p-value', 0.009964815367721095),
#  ('f-value', 3.1393673607131873),
#  ('f p-value', 0.006347592206734527)]

# %% [markdown]
# # Goldfeld-Quandt test

# %%
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(lm.resid, lm.model.exog)
lzip(name, test)
# Out:
# [('F statistic', 0.7041318550274301), ('p-value', 0.827694949936503)]

# %% [markdown]
# # Linearity
# Harvey-Collier multiplier test for Null hypothesis that the linear specification is correct:

# %%
name = ['t value', 'p value']
test = sms.linear_harvey_collier(lm)
lzip(name, test)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-136-f0494e33fabe> in <module>()
#       1 name = ['t value', 'p value']
# ----> 2 test = sms.linear_harvey_collier(lm)
#       3 lzip(name, test)
#
# C:\Users\Bota\Miniconda3\lib\site-packages\statsmodels\sandbox\stats\diagnostic.pyc in linear_harvey_collier(res)
#     915     #B.H. Baltagi, Econometrics, 2011, chapter 8
#     916     #but it matches Gretl and R:lmtest, pvalue at decimal=13
# --> 917     rr = recursive_olsresiduals(res, skip=3, alpha=0.95)
#     918     from scipy import stats
#     919
#
# C:\Users\Bota\Miniconda3\lib\site-packages\statsmodels\sandbox\stats\diagnostic.pyc in recursive_olsresiduals(olsresults, skip, lamda, alpha)
#    1172     y0 = y[:skip]
#    1173     #add Ridge to start (not in jplv
# -> 1174     XTXi = np.linalg.inv(np.dot(x0.T, x0)+lamda*np.eye(nvars))
# ...

# %%
X=wage_simple_log[['Overall','Age','Special','Potential']]
X = sm.add_constant(X) # adding a constant
Y=wage_simple_log['Wage']

# %%
wage_simple.Value.apply(np.log)
sns.pairplot(wage_simple_log[['price', 'mpg','weight','displacement','length','gear_ratio','Foreign','trunk']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-0b8d4701a2c9> in <module>()
# ----> 1 wage_simple.Value.apply(np.log)
#       2 sns.pairplot(wage_simple_log[['price', 'mpg','weight','displacement','length','gear_ratio','Foreign','trunk']])
#
# NameError: name 'wage_simple' is not defined

# %%
# This is a test for heteroskedasticity

import scipy as sp
import statsmodels.api as api

def bp_test(y,x):
    results=api.OLS(y,x).fit()
    residual=results.resid
    
    F=residual**2/(sum(residual**2)/len(residual)) -1
    
    results2=api.OLS(F,x).fit()
    
    fv=results2.fittedvalues
    
    bp=0.5*sum(fv**2)
    
    degree_of_freedom=results2.df_model
    
    p_value=1-sp.stats.chi.cdf(bp,degree_of_freedom)
    
    return bp, degree_of_freedom, p_value

# %%
X=df[['mpg','weight','displacement','length','gear_ratio','Foreign','trunk']]
X = sm.add_constant(X) # adding a constant
Y=df['price']

# %%
bp_test(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-5c5c634d8b3c> in <module>()
# ----> 1 bp_test(X,Y)
#
# <ipython-input-138-b410e87a4e62> in bp_test(y, x)
#       8     residual=results.resid
#       9
# ---> 10     F=residual**2/(sum(residual**2)/len(residual)) -1
#      11
#      12     results2=api.OLS(F,x).fit()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     12.18
# Date:                Mon, 13 May 2019   Prob (F-statistic):           7.03e-10
# Time:                        07:44:20   Log-Likelihood:                -665.03
# No. Observations:                  74   AIC:                             1346.
# Df Residuals:                      66   BIC:                             1364.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
lm.params
# Out:
# Intercept       5604.228483
# mpg              -14.143875
# weight             4.711818
# displacement       8.897957
# length           -84.650877
# gear_ratio       -21.703695
# Foreign         3802.132646
# trunk            -20.114860
# dtype: float64

# %% [markdown]
# ### These are the residuals, which we could manually add to our measured values to obtain the line of best fit

# %%
lm.resid
# Out:
# 0      -32.315674
# 1    -3774.268822
# 2     -480.341360
# 3     -585.756161
# 4     -656.473183
# 5       26.117072
# 6      658.267402
# 7      -15.507180
# 8     2585.069302
# 9    -2070.586685
# 10     954.609413
# 11    5241.560067
# 12    4849.698964
# 13     150.299234
# 14    -880.177963
# 15    -813.411523
# 16     170.557052
# 17    -546.303204
# 18   -2773.240949
# 19    1978.877642
# 20   -3298.090900
# 21   -1450.378650
# 22     463.393243
# 23    2520.607892
# 24     568.265325
# 25     -82.092399
# 26    2245.913635
# 27    4696.498786
# 28    -319.983492
# 29   -2755.009818
#          ...
# 44    3961.084688
# 45   -1575.264581
# 46    -463.955820
# 47   -1852.548697
# 48     106.398544
# 49    -494.670174
# 50   -1568.870406
# 51     241.405847
# 52    2394.199149
# 53    1628.203517
# 54    2422.851401
# 55    -482.150899
# 56    -387.906091
# 57   -1161.310022
# 58     576.788584
# 59   -1760.026257
# 60      66.978702
# 61    -828.668484
# 62   -1743.214673
# ...

# %%
from statsmodels.stats.outliers_influence import summary_table
# %matplotlib inline
# OLS confidence intervals
st, data, ss2 = summary_table(lm, alpha=0.05)

fittedvalues = data[:,2]
predict_mean_se  = data[:,3]
predict_mean_ci_low, predict_mean_ci_upp = data[:,4:6].T
predict_ci_low, predict_ci_upp = data[:,6:8].T

# %%
ss2
# Out:
# ['Obs',
#  'Dep Var\nPopulation',
#  'Predicted\nValue',
#  'Std Error\nMean Predict',
#  'Mean ci\n95% low',
#  'Mean ci\n95% upp',
#  'Predict ci\n95% low',
#  'Predict ci\n95% upp',
#  'Residual',
#  'Std Error\nResidual',
#  'Student\nResidual',
#  "Cook's\nD"]

# %%
plt.figure(figsize=(200,200))
sns.lmplot(data=df,y='price',x='weight', size=6, aspect=1.5)
plt.title("Distribution of wages based on the weight")
plt.xlabel("weight")
plt.ylabel("price (Thousand Euro)")
# Out:
# C:\Users\Bota\Miniconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(200,200))
df_log=df
df_log.price=df.price.apply(np.log)
sns.lmplot(data=df_log,y='price',x='weight', size=6, aspect=1.5)
plt.title("Distribution of wages based on the Players Age and Overall Performance")
plt.xlabel("weight")
plt.ylabel("price)")
# Out:
# C:\Users\Bota\Miniconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X=df[['mpg','weight','displacement','length','gear_ratio','Foreign','trunk']]
X = sm.add_constant(X) # adding a constant
Y=df['price']
model = sm.OLS(Y,X).fit()
#predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     12.18
# Date:                Mon, 13 May 2019   Prob (F-statistic):           7.03e-10
# Time:                        08:30:36   Log-Likelihood:                -665.03
# No. Observations:                  74   AIC:                             1346.
# Df Residuals:                      66   BIC:                             1364.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         5604.2285   6078.517      0.922      0.360   -6531.923    1.77e+04
# ...

# %%
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(model.resid, model.model.exog)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 18.484589126965286),
#  ('p-value', 0.00996481536772116),
#  ('f-value', 3.1393673607131842),
#  ('f p-value', 0.006347592206734579)]

# %%
df.head()
# Out:
#             make     price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord  8.318498   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer  8.465689   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit  8.242493   22    NaN       3.0     12    2640     168    35
# 3  Buick Century  8.479699   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra  8.965335   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio   foreign  Domestic  Foreign
# 0           121        3.58  Domestic         1        0
# 1           258        2.53  Domestic         1        0
# 2           121        3.08  Domestic         1        0
# 3           196        2.93  Domestic         1        0
# 4           350        2.41  Domestic         1        0

# %%
df.make.nunique()
# Out:
# 74

# %%
df2 = df.set_index('make')

# %%
df2.head()
# Out:
#                   price  mpg  rep78  headroom  trunk  weight  length  turn  \
# make
# AMC Concord    8.318498   22    3.0       2.5     11    2930     186    40
# AMC Pacer      8.465689   17    3.0       3.0     11    3350     173    40
# AMC Spirit     8.242493   22    NaN       3.0     12    2640     168    35
# Buick Century  8.479699   20    3.0       4.5     16    3250     196    40
# Buick Electra  8.965335   15    4.0       4.0     20    4080     222    43
#
#                displacement  gear_ratio   foreign  Domestic  Foreign
# make
# AMC Concord             121        3.58  Domestic         1        0
# AMC Pacer               258        2.53  Domestic         1        0
# AMC Spirit              121        3.08  Domestic         1        0
# Buick Century           196        2.93  Domestic         1        0
# Buick Electra           350        2.41  Domestic         1        0

# %%
df2.corr()
# Out:
#                  price       mpg     rep78  headroom     trunk    weight  \
# price         1.000000 -0.491000  0.052137  0.109804  0.358813  0.540456
# mpg          -0.491000  1.000000  0.402340 -0.413803 -0.581585 -0.807175
# rep78         0.052137  0.402340  1.000000 -0.147998 -0.157243 -0.400344
# headroom      0.109804 -0.413803 -0.147998  1.000000  0.662011  0.483456
# trunk         0.358813 -0.581585 -0.157243  0.662011  1.000000  0.672206
# weight        0.540456 -0.807175 -0.400344  0.483456  0.672206  1.000000
# length        0.458949 -0.795779 -0.360565  0.516295  0.726596  0.946009
# turn          0.308442 -0.719186 -0.496131  0.424465  0.601059  0.857443
# displacement  0.483042 -0.705643 -0.411943  0.474491  0.608635  0.894896
# gear_ratio   -0.283770  0.616177  0.410340 -0.377852 -0.508665 -0.759258
# Domestic     -0.087027 -0.393397 -0.592237  0.293853  0.359435  0.592830
# Foreign       0.087027  0.393397  0.592237 -0.293853 -0.359435 -0.592830
#
# ...

# %%
wmod = smf.wls("A2 ~ A + B + C + D + E + F + G + H + J + K +N -1", data=fpe, weights = 1/fpe.EI ).fit()
wmod.params

# %%
wmod= smf.wls(formula='price ~ mpg+weight+displacement+length+gear_ratio+Foreign+trunk', data =df2,weights = 1/wts).fit()
model = wmod.summary()
print(model)
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.583
# Model:                            WLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     13.18
# Date:                Mon, 13 May 2019   Prob (F-statistic):           1.71e-10
# Time:                        09:17:00   Log-Likelihood:                -9.5819
# No. Observations:                  74   AIC:                             35.16
# Df Residuals:                      66   BIC:                             53.60
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        8.4996      0.857      9.919      0.000       6.789      10.210
# ...

# %%
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(wmod.resid, wmod.model.exog)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 6.961720972572266),
#  ('p-value', 0.43287632866180625),
#  ('f-value', 0.9791284085444093),
#  ('f p-value', 0.4539502291973637)]

# %%
wmod.params
# Out:
# Intercept       8.039494
# mpg            -0.003645
# weight          0.000520
# displacement    0.001112
# length         -0.007369
# gear_ratio      0.029233
# Foreign         0.528155
# trunk           0.001679
# dtype: float64

# %%
lmod = smf.ols(formula='price ~ mpg+weight+displacement+length+gear_ratio+Foreign+trunk', data=df2).fit()
plt.scatter(lmod.fittedvalues,lmod.resid)
plt.axhline(0)
plt.show()

# %%
lmod.params
# Out:
# Intercept       7.826779
# mpg            -0.002122
# weight          0.000851
# displacement   -0.000024
# length         -0.009072
# gear_ratio     -0.191123
# Foreign         1.035071
# trunk           0.012899
# dtype: float64

# %%
gamma = np.mean(np.abs(lmod.resid) - df2.weight)
lmod = smf.wls(formula='price ~ mpg+weight+displacement+length+gear_ratio+Foreign+trunk', data=df2, weights=np.sqrt(1/(gamma+df2.weight))).fit()
gamma, lmod.params
# Out:
# C:\Users\Bota\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt
# (-3019.2587100337864, Intercept       7.826779
#  mpg            -0.002122
#  weight          0.000851
#  displacement   -0.000024
#  length         -0.009072
#  gear_ratio     -0.191123
#  Foreign         1.035071
#  trunk           0.012899
#  dtype: float64)

# %%
weights=np.sqrt(1/(gamma+df2.weight))
plt.scatter(df2.weight, weights)
plt.show()
# Out:
# C:\Users\Bota\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.

# %%
exog = df2.drop('price',axis=1)

# %%
exog = sm.add_constant(exog)

# %%
rlmod = sm.RLM(df2['price'].astype(float),exog.astype(float)).fit()

# %%
rlmod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Robust linear Model Regression Results
# ...
# Dep. Variable:                  price   No. Observations:                   74
# Model:                            RLM   Df Residuals:                       63
# Method:                          IRLS   Df Model:                           10
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 13 May 2019
# Time:                        09:16:01
# No. Iterations:                    21
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            8.2729      0.764     10.831      0.000       6.776       9.770
# mpg             -0.0099      0.009     -1.097      0.273      -0.028       0.008
# ...

# %%
wts = rlmod.weights

# %%
wts
# Out:
# make
# AMC Concord          1.000000
# AMC Pacer            1.000000
# AMC Spirit           1.000000
# Buick Century        1.000000
# Buick Electra        1.000000
# Buick LeSabre        1.000000
# Buick Opel           1.000000
# Buick Regal          1.000000
# Buick Riviera        0.742350
# Buick Skylark        1.000000
# Cad. Deville         1.000000
# Cad. Eldorado        0.465245
# Cad. Seville         0.487286
# Chev. Chevette       1.000000
# Chev. Impala         1.000000
# Chev. Malibu         1.000000
# Chev. Monte Carlo    1.000000
# Chev. Monza          1.000000
# Chev. Nova           1.000000
# Dodge Colt           1.000000
# Dodge Diplomat       1.000000
# Dodge Magnum         1.000000
# Dodge St. Regis      1.000000
# Ford Fiesta          1.000000
# Ford Mustang         1.000000
# Linc. Continental    1.000000
# Linc. Mark V         1.000000
# Linc. Versailles     0.523714
# Merc. Bobcat         1.000000
# Merc. Cougar         1.000000
#                        ...
# ...

# %%
df2.head()
# Out:
#                   price  mpg  rep78  headroom  trunk  weight  length  turn  \
# make
# AMC Concord    8.318498   22    3.0       2.5     11    2930     186    40
# AMC Pacer      8.465689   17    3.0       3.0     11    3350     173    40
# AMC Spirit     8.242493   22    NaN       3.0     12    2640     168    35
# Buick Century  8.479699   20    3.0       4.5     16    3250     196    40
# Buick Electra  8.965335   15    4.0       4.0     20    4080     222    43
#
#                displacement  gear_ratio  Foreign
# make
# AMC Concord             121        3.58        0
# AMC Pacer               258        2.53        0
# AMC Spirit              121        3.08        0
# Buick Century           196        2.93        0
# Buick Electra           350        2.41        0

# %%
df2 =df2.drop(columns ='foreign')

# %%
df2.dtypes
# Out:
# price           float64
# mpg               int64
# rep78           float64
# headroom        float64
# trunk             int64
# weight            int64
# length            int64
# turn              int64
# displacement      int64
# gear_ratio      float64
# Foreign           int32
# dtype: object

# %%
df2['Foreign']=df2['Foreign'].astype(int)

# %%
exog.head()
# Out:
#                const  mpg  rep78  headroom  trunk  weight  length  turn  \
# make
# AMC Concord      1.0   22    3.0       2.5     11    2930     186    40
# AMC Pacer        1.0   17    3.0       3.0     11    3350     173    40
# AMC Spirit       1.0   22    NaN       3.0     12    2640     168    35
# Buick Century    1.0   20    3.0       4.5     16    3250     196    40
# Buick Electra    1.0   15    4.0       4.0     20    4080     222    43
#
#                displacement  gear_ratio  Foreign
# make
# AMC Concord             121        3.58        0
# AMC Pacer               258        2.53        0
# AMC Spirit              121        3.08        0
# Buick Century           196        2.93        0
# Buick Electra           350        2.41        0

# %%
exog.isnull().sum()
# Out:
# const           0
# mpg             0
# rep78           5
# headroom        0
# trunk           0
# weight          0
# length          0
# turn            0
# displacement    0
# gear_ratio      0
# Foreign         0
# dtype: int64

# %%
exog.fillna(exog.mean(), inplace=True)

# %%
exog.isnull().all().all()
# Out:
# False
